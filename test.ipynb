# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"D:\Jitendra_lodhi\Texas\Brazoria\Transaction_Log\Raw_Data\us_tx_48039_data_trxlog_main_bronze_20260327.csv")
df
# Out:
# C:\Users\jitendra.lodhi\AppData\Local\Temp\ipykernel_21072\3294951642.py:1: DtypeWarning: Columns (0,1,2,12,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"D:\Jitendra_lodhi\Texas\Brazoria\Transaction_Log\Raw_Data\us_tx_48039_data_trxlog_main_bronze_20260327.csv")
#                         instr input_volume       input_page document_type  \
# 0                  2013058286         2013            58286          DEED
# 1                  2014007998           14             7998          DEED
# 2                  2014007111           14             7111          DEED
# 3                  2014028285         2014            28285          DEED
# 4                  2014017729           14            17729          DEED
# ...                       ...          ...              ...           ...
# 291142      2025011948/017387         2025    011948/017387           NaN
# ...
